# %%
import pandas as pd
import cobra

from cobra.io import load_model

import numpy as np
import pickle

# %% [markdown]
# ## Read the model

# %%
model = cobra.io.read_sbml_model('models\\Recon3D.xml')

# %% [markdown]
# ## Read the transcriptomics data

# %% [markdown]
# Projection of gene names to ids

# %%
gene_id_name = {}
gene_name_id = {}

for g in model.genes[1:]:
    gene_id_name[g.id] = g.name
    gene_name_id[g.name] = g.id

# %% [markdown]
# Read the expression data

# %%
df_control = pd.read_csv("data\\data_control.txt")
df_kd = pd.read_csv("data\\data_kd.txt")

# %% [markdown]
# Add ids to expression data

# %%
df_control['gene_id'] = df_control['gene'].map(lambda x: gene_name_id[x] if x in gene_name_id else "")
df_kd['gene_id'] = df_kd['gene'].map(lambda x: gene_name_id[x] if x in gene_name_id else "")

# %% [markdown]
# Keep only genes that are present in the model

# %%
df_control = df_control[df_control['gene_id'] != ""]
df_kd = df_kd[df_kd['gene_id'] != ""]

# %%
len(df_control), len(df_kd)
# Out:
# (2019, 2019)

# %%
df_control.describe()
# Out:
#              value
# count  2019.000000
# mean      8.288940
# std       3.151708
# min       3.310000
# 25%       5.595000
# 50%       7.610000
# 75%      10.795000
# max      17.540000

# %%
df_kd.describe()
# Out:
#              value
# count  2019.000000
# mean      8.324889
# std       3.169539
# min       3.230000
# 25%       5.605000
# 50%       7.680000
# 75%      10.890000
# max      17.480000

# %% [markdown]
# ## Integrate transcriptomics data

# %% [markdown]
# CORDA algorithm
#
# * https://resendislab.github.io/corda/
# * https://github.com/resendislab/corda
#
# Lahko nastavim, da mora model biti zmožen producirati biomaso
# ```
# met_prod (Optional[list]): Additional metabolic targets that have to be
#             achieved by the model. Can be a single object or list of objects.
#             List elements can be given in various forms:
#             (1) A string naming a metabolite in the model will ensure that the
#             metabolite can be produced.
#             For instance: met_prod = ["pi_c", "atp_c"]
#             (2) A dictionary of metabolite -> int will define an irreversible
#             reaction that must be able to carry flux.
#             For instance: met_prod = {"adp_c": -1, "pi_c": -1, "atp_c": 1}
#             (3) A string representation of a reversible or irreversible
#             reaction that must be able to carry flux.
#             For instance: met_prod = "adp_c + pi_c -> atp_c"
#
# ```
# Primer, ki bi moral delovati:
# ```Python
# met_prod = model.reactions.BIOMASS_maintenance.build_reaction_string()
# met_prod = met_prod.replace("-->", "->")
# ```
#
# https://github.com/resendislab/corda/blob/main/corda/corda.py

# %% [markdown]
# #### Extract biomass function from the model

# %%
biomass = model.reactions.BIOMASS_maintenance.build_reaction_string().replace("-->", "->")
biomass
# Out:
# '0.50563 ala__L_c + 0.35926 arg__L_c + 0.27942 asn__L_c + 0.35261 asp__L_c + 20.7045 atp_c + 0.020401 chsterol_c + 0.011658 clpn_hs_c + 0.039036 ctp_c + 0.046571 cys__L_c + 0.27519 g6p_c + 0.326 gln__L_c + 0.38587 glu__L_c + 0.53889 gly_c + 0.036117 gtp_c + 20.6508 h2o_c + 0.12641 his__L_c + 0.28608 ile__L_c + 0.54554 leu__L_c + 0.59211 lys__L_c + 0.15302 met__L_c + 0.023315 pail_hs_c + 0.15446 pchol_hs_c + 0.055374 pe_hs_c + 0.002914 pglyc_hs_c + 0.25947 phe__L_c + 0.41248 pro__L_c + 0.005829 ps_hs_c + 0.39253 ser__L_c + 0.017486 sphmyln_hs_c + 0.31269 thr__L_c + 0.013306 trp__L_c + 0.15967 tyr__L_c + 0.053446 utp_c + 0.35261 val__L_c -> 20.6508 adp_c + 20.6508 h_c + 20.6508 pi_c'

# %% [markdown]
# ### Model integration

# %%
from corda import reaction_confidence
from corda import CORDA

# %%
def val_to_score(val, thr0, thr1, thr2, thr3):
    if val < thr0:
        return -1
    elif val < thr1:
        return 0
    elif val < thr2:
        return 1
    elif val < thr3:
        return 2
    else:
        return 3

# %% [markdown]
# #### Parameters

# %%
require_biomass = True
perc0 = 25 # below this ... inactive
perc1 = 50 # else, below this ... not sure
perc2 = 75 # else, below this ...  low confidence
perc3 = 95 # else, below this ... medium confidence
# else high confidence (above perc3)

# %%
folder = "models\\biomass" if require_biomass else "models\\no_biomass"
folder
# Out:
# 'models\\biomass'

# %% [markdown]
# ### Control

# %%
thr0 = np.percentile(df_control.value, perc0)
thr1 = np.percentile(df_control.value, perc1)
thr2 = np.percentile(df_control.value, perc2)
thr3 = np.percentile(df_control.value, perc3)

# %%
#gene_conf_control = {g_id:-1 if val < thr0 else 1 if val < thr1 else 2 if val < thr2 else 3 for (g_id, val) in zip(df_control['gene_id'], df_control['value'])}
gene_conf_control = {g_id : val_to_score(val, thr0, thr1, thr2, thr3) for (g_id, val) in zip(df_control['gene_id'], df_control['value'])}

# %%
conf_control = {}
for r in model.reactions:
    conf_control[r.id] = reaction_confidence(r, gene_conf_control)

# %%
conf_control
# Out:
# {'24_25DHVITD3tm': 0,
#  '25HVITD3t': 0,
#  'COAtl': 0,
#  'EX_5adtststerone_e': 0,
#  'EX_5adtststerones_e': 0,
#  'EX_5fthf_e': 0,
#  'EX_5htrp_e': 0,
#  'EX_5mthf_e': 0,
#  'EX_5thf_e': 0,
#  'EX_6dhf_e': 0,
#  '24_25VITD3Hm': 3,
#  '24NPHte': 0,
#  '10FTHF7GLUtl': 0,
#  '10FTHFtm': 0,
#  '11DOCRTSLtr': 0,
#  '13DAMPPOX': 1,
#  '24_25DHVITD2t': 0,
#  '24_25DHVITD2tm': 0,
#  '24_25DHVITD3t': 0,
#  '25VITD2Hm': 0,
#  '2AMACHYD': -1,
#  '2AMACSULT': 0,
#  '2AMADPTm': 0,
#  '2MCITt': 0,
#  '2OXOADOXm': 2,
#  '2OXOADPTm': 0,
#  '34DHPHEt': 1,
#  '34DHXMANDACOX': 1,
#  '34HPLFM': 0,
#  '3AIBtm': 0,
#  '3HAO': -1,
#  '3MOBt2im': 0,
#  '3MOPt2im': 0,
#  '3MOXTYROX': 0,
#  '3SALAOX': 0,
#  '42A12BOOX': 1,
#  '4HBZCOAFm': 0,
#  '4HBZFm': 0,
#  '4HDEBRISOQUINEte': 0,
#  '4HOXPACDOX_NADP': 1,
#  '4MOPt2im': 0,
#  '4MPTNLte': 0,
#  '4NPHSULT': 0,
#  '4PYRDX': 0,
#  '5ADTSTSTERONEGLCtr': 0,
#  '5ADTSTSTERONESULT': 0,
#  '5ADTSTSTERONEte': 0,
#  '5FTHFt2_1': 0,
#  '5HOXINOXDA': 0,
#  '5THFtl': 0,
#  '5THFtm': 0,
#  '7DHCHSTEROLtr': 0,
#  '7DHFtm': 0,
#  'A4GALTc': -1,
#  'A4GALTg': -1,
#  'A4GNT2g': -1,
#  'AACTtm': 0,
#  'ABO1g': -1,
#  'ABO4g': -1,
#  'ABO5g': -1,
#  'ABO6g': -1,
#  'ABO7g': -1,
#  'ABO9g': -1,
#  'ABTArm': 0,
#  'ABTt': 0,
#  'ABUTt2rL': 1,
#  'ACACT10m': 2,
#  'ACACT5p': 2,
#  'ACACT8p': 2,
#  'ACACT9p': 2,
#  'ACALDtr': 0,
#  'ACALDtx': 0,
#  'ACCOALm': 1,
#  'ACCOAtr': 1,
#  'ACETONEt2': 2,
#  'ACGAGBSIDEtl': 0,
#  'ACGALFUCGALACGALFUCGALACGLCGAL14ACGLCGALGLUSIDEte': 0,
#  'ACGALtlg': 0,
#  'ACGAMK': 2,
#  'ACGAMPM': 2,
#  'ACGAMtly': 0,
#  'ACGBGBSIDEtl': 0,
#  'ACHtn': 0,
#  'ACHVESSEC_1': -1,
#  'ACN13ACNGALGBSIDEtg': 0,
#  'ACNACNGAL14ACGLCGALGLUSIDEtg': 0,
#  'ACNACNGALGBSIDEtg': 0,
#  'ACNAMlt': 1,
#  'ACNAMtn': 0,
#  'ACNGALACGLCGAL14ACGLCGALGLUSIDEte': 0,
#  'ACNML': 0,
#  'ACOAD10m': 2,
#  'ACOAD8m': 1,
#  'ACOAD9m': 2,
#  'ACOAO7p': 2,
#  'ACODA': 0,
#  'ACONTm': 2,
#  'ACP1_FMN': 2,
#  'ACS2': 1,
#  'ACSRTNMT': -1,
#  'ACt2r': 0,
#  'ADEt': 0,
#  'ADK3': 2,
#  'ADK3m': 2,
#  'ADKd': 2,
#  'ADMDC': 3,
#  'ADNt4': 0,
#  'ADNtl': -1,
#  'ADNtm': 2,
#  'ADPMAN': 2,
#  'ADPRIBt': -1,
#  'ADRNCOAtx': 0,
#  'ADRNCRNt': 0,
#  'ADSL2r': 2,
#  'AG13T16g': 2,
#  'AG13T18g': 2,
#  'AG13T2g': 2,
#  'AGMTm': -1,
#  'AGTim': 0,
#  'AHANDROSTANGLCte': -1,
#  'AHEXASE2ly': 3,
#  'AIRCr': 3,
#  'AKGMALtm': 2,
#  'AKGt4_3': 0,
#  'AKR1C41': 0,
#  'AKR1D': -1,
#  'ALAGLYexR': -1,
#  'ALASERNaEx': 2,
#  'ALASm': 2,
#  'ALATHRNaEx': 2,
#  'ALCD21_D': 2,
#  'ALCD22_D': 2,
#  'ALCD2y': 1,
#  'ALDD20xm': 1,
#  'ALDD2xm': 1,
#  'ALDD2y': 2,
#  'ALDSTRNte': 0,
#  'ALDSTRNtm': 0,
#  'ALOX15': 0,
#  'ALR2': 3,
#  'ALR3': 3,
#  'AMACR2p': 1,
#  'AMACRp': 1,
#  'AMETr': 0,
#  'AMETt2m': 0,
#  'AMPDA': 1,
#  'AMY2e': 3,
#  'ANDRSTRNGLCte': -1,
#  'ANDRSTRNGLCtr': 0,
#  'ANDRSTRNtr': 0,
#  'ANTIPYRENEte': 0,
#  'APOCFm': 0,
#  'APOC_LYS_BTNP': 0,
#  'APRTO2': 0,
#  'ARAB_Lt': 0,
#  'ARABR': 3,
#  'ARACHDCOAtx': 0,
#  'ARACHDt2': 1,
#  'ARACHt': 0,
#  'ARGDCm': 0,
#  'ARGLYSex': 2,
#  'ARGSS': 1,
#  'ARGt4': -1,
#  'ARTCOAL3_cho': 0,
#  'R_group_phosphotase_2': 0,
#  'R_group_phosphotase_3': 0,
#  'ASCBOX_1': 0,
#  'ASCBt': 0,
#  'ASNCYSNaEx': 2,
#  'ASNGLNNaEx': 2,
#  'ASNNm': 1,
#  'ASNS1': 2,
#  'ASNt4': 3,
#  'ASPDxt': 0,
#  'ASPGLUm': 2,
#  'ASPNATm': 0,
#  'ASPt6': 0,
#  'ASPTAm': 2,
#  'ATP1ter': 0,
#  'BILGLCURte': -1,
#  'BILIRED': 2,
#  'EX_6htststerone_e': 0,
#  'ATPasel_1': 1,
#  'ATPtn': 0,
#  'ATPtx': 0,
#  'AVITE2t': 0,
#  'B3GALT3g': 1,
#  'B3GALT42g': -1,
#  'B3GALTg': 0,
#  'B3GNT11g': 2,
#  'B3GNT310g': 0,
#  'B3GNT315g': 0,
#  'B3GNT31g': 0,
#  'B3GNT34g': 0,
#  'B3GNT37g': 0,
#  'B3GNT39g': 0,
#  'B3GNT51g': 1,
#  'BAAT1x': -1,
#  'BAAT3x': -1,
#  'BACCL': 0,
#  'BALAVECSEC_1': -1,
#  'BDHm': 0,
#  'BETALDHxm': 0,
#  'BHBtm': 0,
#  'BHMT': 2,
#  'BILDGLCURt': 0,
#  'BTNDm': 1,
#  'BTNPL': 0,
#  'BTNt2m': 2,
#  'BTNt3i_1': 1,
#  'BVITEt': 0,
#  'BZtr': 0,
#  'C160CPT1': 1,
#  'C160CPT2': 1,
#  'C160CRNt': 0,
#  'C161CPT1': 1,
#  'C161CPT12': 1,
#  'C161CPT2': 0,
#  'C161CRN2t': 0,
#  'C161CRNt': 0,
#  'C180CPT1': 1,
#  'C181CPT1': 1,
#  'C181CRNt': 0,
#  'C204CPT1': 1,
#  'C204CPT2': 0,
#  'C226COAtx': 0,
#  'C226CPT1': 1,
#  'C226CPT2': 0,
#  'C226CRNt': 0,
#  'C3STDH1r': 2,
#  'C4STMO1r': 3,
#  'C4STMO2Pr': 2,
#  'CAATPS_1': 2,
#  'CAROtr': 0,
#  'CAt7r': 0,
#  'CATm': -1,
#  'CATp': -1,
#  'CBL2tm': 1,
#  'CBPPer': 2,
#  'CBR2': 2,
#  'CDIPTr': 2,
#  'CDPDAGtm': 0,
#  'CDS': 2,
#  'CERT1gt': 2,
#  'CERT1rt': 2,
#  'CERT2rt': 2,
#  'CH25H': -1,
#  'CHATn': 1,
#  'CHLP': 0,
#  'CHOLD2m': -1,
#  'CHOLK': 1,
#  'CHOLPtl': 0,
#  'CHOLtn': 0,
#  'CHOLtr': 0,
#  'CHSTEROLt3': 0,
#  'CITRtm': 0,
#  'CITtam': 1,
#  'CK_cho': 0,
#  'CLHCO3tex2': 0,
#  'CLOXAtex2': 0,
#  'CLPNDCOAtx': 0,
#  'CLPNDCPT1': 1,
#  'CLPNDt': 0,
#  'CMPACNAtn': 0,
#  'ACNMCT': 2,
#  'CO2tg': 0,
#  'CO2tm': 0,
#  'COAtim': 1,
#  'COKECBESr': 0,
#  'COQ3m': 0,
#  'COQ6m': 0,
#  'COQ7m': 2,
#  'CORE3GTg': 0,
#  'CORE6GTg': -1,
#  'CORE7GTg': 0,
#  'CREATt4_2_r': 1,
#  'CREATtmdiffir': 0,
#  'CRMPte': 0,
#  'CRNCAR3tp': 0,
#  'CRNCARtp': 0,
#  'CRNt': 1,
#  'CRNtHa': 1,
#  'CRNtuNa': 1,
#  'CRTNsyn_cho': 0,
#  'CRTSLt': 0,
#  'CRTSLtm': 0,
#  'CRTSLtr': 0,
#  'CRVNCtr': 0,
#  'CSAPASEly': 0,
#  'CSCPASEly': 0,
#  'CSEPASEly': 0,
#  'CSNAT2m': 0,
#  'CSNAT2x': 2,
#  'CSNAT3x': 0,
#  'CSNATm': 0,
#  'CSNATp': 0,
#  'CSNATr': 0,
#  'CSPG_Atly': 0,
#  'CSPG_Ct': 0,
#  'CSPG_Ctly': 0,
#  'CSPG_Dt': 0,
#  'CSPG_Dtly': 0,
#  'CTPtn': 0,
#  'CYANt': 0,
#  'CYANtm': 0,
#  'CYSALANaEx': 2,
#  'CYSASNNaEx': 2,
#  'CYSGLYex': 0,
#  'CYSO': 0,
#  'CYSSERNaEx': 2,
#  'CYStec': 1,
#  'CYSTGLUex': 2,
#  'CYTD': -1,
#  'CYTDn': -1,
#  'CYTDt': 2,
#  'CYTDtl': -1,
#  'CYTK12': 2,
#  'CYTK12n': 2,
#  'CYTK13n': 2,
#  'CYTK14': 2,
#  'CYTK1m': -1,
#  'CYTK2n': 2,
#  'CYTK3': 2,
#  'CYTK4': 2,
#  'CYTK5n': 2,
#  'CPK1': 2,
#  'CYTK6n': 2,
#  'CYTK7': 2,
#  'CYTK7n': 2,
#  'CYTK8': 2,
#  'CYTK8n': 2,
#  'DADNK': 0,
#  'DAG_HSter': 0,
#  'DAGK_hs': 1,
#  'DARGOp': -1,
#  'DASCBH': 0,
#  'DASPO1p': 0,
#  'DATPtn': 0,
#  'DCK1m': 0,
#  'DCK1n': 2,
#  'DLNLCGCPT2': 0,
#  'DCSPTN1CPT1': 1,
#  'DCSPTN1CRNt': 0,
#  'DCSPTN1t': 0,
#  'DCTPtn': 0,
#  'DCYTD': -1,
#  'DCYTDn': -1,
#  'DCYTt': 0,
#  'DECDPtm': 0,
#  'DEDOLP2_L': 0,
#  'DESAT18_10': 3,
#  'DESAT18_6': 3,
#  'DESAT18_12': 3,
#  'DESAT22_2p': 0,
#  'DESAT24_1': 3,
#  'DGCHOLte': 0,
#  'DGSNt': 0,
#  'DGSNtm': 0,
#  'DHCRD2': 3,
#  'DHDPBMTm': 0,
#  'DHEASt': 2,
#  'DHEASULT': 0,
#  'DHEAtr': 0,
#  'DHFtl': 0,
#  'DHFtm': 0,
#  'DHORD9': 2,
#  'DHPM1': 3,
#  'DIGALSGALSIDEtg': 0,
#  'DIGALSIDEtl': 0,
#  'DITPtn': 0,
#  'D_LACt2': 2,
#  'DLNLCGCPT1': 1,
#  'DM_Asn_X_Ser_Thr_l': 0,
#  'DM_core5_g': 0,
#  'DM_dem2emgacpail_prot_hs_r': 0,
#  'DM_dgpi_prot_hs_r': 0,
#  'DM_dsT_antigen_g': 0,
#  'DM_kdn_c': 0,
#  'DM_melanin_c': 0,
#  'DM_n5m2masn_g': 0,
#  'DM_oretn_n': 0,
#  'DM_Ser_Thr_l': 0,
#  'DM_Ser_Gly_Ala_X_Gly_l': 0,
#  'DM_sprm_c': 0,
#  'DMANTIPYRINEte': 0,
#  'DMATTx': 2,
#  'DMGDHm': 1,
#  'DMGtm': 0,
#  'DMHPTCRNCPT2': 0,
#  'DMHPTCRNte': 0,
#  'C110CPT2m': 0,
#  'DMNONCRNt': 0,
#  'DNADtn': 0,
#  'DNDPt10m': 1,
#  'DNDPt11m': 1,
#  'DNDPt13m': 1,
#  'DNDPt14m': 1,
#  'DNDPt15m': 1,
#  'DNDPt16m': 1,
#  'DNDPt17m': 1,
#  'DNDPt18m': 1,
#  'DNDPt1m': 1,
#  'DNDPt20m': 1,
#  'DNDPt21m': 1,
#  'DNDPt25m': 1,
#  'DNDPt28m': 1,
#  'DNDPt32m': 1,
#  'DNDPt37m': 1,
#  'DNDPt38m': 1,
#  'DNDPt39m': 1,
#  'DNDPt40m': 1,
#  'DNDPt42m': 1,
#  'DNDPt43m': 1,
#  'DNDPt45m': 1,
#  'DNDPt49m': 1,
#  'DNDPt50m': 1,
#  'DNDPt52m': 1,
#  'DNDPt55m': 1,
#  'DNDPt56m': 1,
#  'DNDPt57m': 1,
#  'DNDPt59m': 1,
#  'DNDPt5m': 1,
#  'DNDPt60m': 1,
#  'DNDPt61m': 1,
#  'DNDPt62m': 1,
#  'DNDPt63m': 1,
#  'DNDPt6m': 1,
#  'DOLGPP_Ler': 0,
#  'DOLICHOL_Lter': 0,
#  'DOLICHOL_Uter': 0,
#  'DOLK_U': 0,
#  'DOLPH_Uer': 1,
#  'DOLPMT_U': 0,
#  'DOLP_Lter': 0,
#  'DOLP_Uter': 0,
#  'DOPAt4_2_r': 1,
#  'DOPAtu': 1,
#  'DOPAVESSEC_1': 0,
#  'DPCOAtl': 0,
#  'DPGase': 2,
#  'DSAT': 0,
#  'DTDPtn': 0,
#  'DUDPtn': 0,
#  'DURAD': 2,
#  'DURAD2': 2,
#  'DURIK1': 2,
#  'DURIt': 0,
#  'DUTPDPm': 2,
#  'EBASTINEOHtr': 0,
#  'EBASTINEte': 0,
#  'ECOAH12m': 2,
#  'ECOAH9m': 2,
#  'EICOSTETCPT1': 1,
#  'ENGASE2ly': 0,
#  'ESTRADIOLGLCtr': 0,
#  'ESTRADIOLt': 0,
#  'ESTRIOLGLCte': -1,
#  'ESTRIOLtr': 0,
#  'ESTRONEGLCt': 2,
#  'ESTRONESt': 2,
#  'ESTRONESt2': -1,
#  'ESTRONEtr': 0,
#  'ETF': 1,
#  'ETFQO': 1,
#  'ETHAK': 2,
#  'EX_10fthf5glu_e': 0,
#  'EX_10fthf6glu_e': 0,
#  'EX_10fthf7glu_e': 0,
#  'EX_11_cis_retfa_e': 0,
#  'EX_13_cis_retnglc_e': 0,
#  'EX_24nph_e': 0,
#  'EX_25hvitd3_e': 0,
#  'EX_2hb_e': 0,
#  'EX_2mcit_e': 0,
#  'EX_34dhphe_e': 0,
#  'EX_35cgmp_e': 0,
#  'EX_4hphac_e': 0,
#  'EX_4mptnl_e': 0,
#  'EX_7dhf_e': 0,
#  'EX_7thf_e': 0,
#  'EX_9_cis_retfa_e': 0,
#  'EX_acetone_e': 0,
#  'EX_acgalfucgalacgalfuc12gal14acglcgalgluside_hs_e': 0,
#  'EX_acnacngal14acglcgalgluside_hs_e': 0,
#  'EX_adp_e': 0,
#  'EX_ahandrostanglc_e': 0,
#  'EX_ala_B_e': 0,
#  'EX_ala__D_e': 0,
#  'EX_aldstrn_e': 0,
#  'EX_andrstrn_e': 0,
#  'EX_andrstrnglc_e': 0,
#  'EX_antipyrene_e': 0,
#  'EX_appnn_e': 0,
#  'EX_arach_e': 0,
#  'EX_avite1_e': 0,
#  'EX_avite2_e': 0,
#  'EX_bhb_e': 0,
#  'EX_bildglcur_e': 0,
#  'EX_biocyt_e': 0,
#  'EX_bvite_e': 0,
#  'EX_caro_e': 0,
#  'EX_carveol_e': 0,
#  'EX_chol_e': 0,
#  'EX_cholate_e': 0,
#  'EX_chtn_e': 0,
#  'EX_clpnd_e': 0,
#  'EX_coumarin_e': 0,
#  'EX_creat_e': 0,
#  'EX_crmp_hs_e': 0,
#  'EX_crn_e': 0,
#  'EX_crtstrn_e': 0,
#  'EX_crvnc_e': 0,
#  'EX_cspg_c_e': 0,
#  'EX_cspg_e_e': 0,
#  'EX_cyan_e': 0,
#  'EX_dag_hs_e': 0,
#  'EX_dcsptn1_e': 0,
#  'EX_dhdascb_e': 0,
#  'EX_dheas_e': 0,
#  'EX_dhf_e': 0,
#  'EX_digalsgalside_hs_e': 0,
#  'EX_dlnlcg_e': 0,
#  'EX_dmantipyrine_e': 0,
#  'EX_dmhptcrn_e': 0,
#  'EX_dopa_e': 0,
#  'EX_eaflatoxin_e': 0,
#  'EX_ebastine_e': 0,
#  'EX_eicostet_e': 0,
#  'EX_estradiolglc_e': 0,
#  'EX_fucacngalacglcgalgluside_hs_e': 0,
#  'EX_fucfuc12gal14acglcgalgluside_hs_e': 0,
#  'EX_fucfucfucgalacglc13galacglcgal14acglcgalgluside_hs_e': 0,
#  'EX_fucfucgalacglcgalgluside_hs_e': 0,
#  'EX_fucgal14acglcgalgluside_hs_e': 0,
#  'EX_fucgalgbside_hs_e': 0,
#  'EX_fuc__L_e': 0,
#  'EX_galacglcgalgbside_hs_e': 0,
#  'EX_galfucgalacglcgal14acglcgalgluside_hs_e': 0,
#  'EX_gd1c_hs_e': 0,
#  'EX_gdp_e': 0,
#  'EX_gluala_e': 0,
#  'EX_glyc__S_e': 0,
#  'EX_gp1calpha_hs_e': 0,
#  'EX_gq1balpha_hs_e': 0,
#  'EX_gsn_e': 0,
#  'EX_gt1a_hs_e': 0,
#  'EX_gthox_e': 0,
#  'EX_ha_e': 0,
#  'EX_ha_pre1_e': 0,
#  'EX_hcoumarin_e': 0,
#  'EX_hdcea_e': 0,
#  'EX_hexc_e': 0,
#  'EX_hom__L_e': 0,
#  'EX_hspg_e': 0,
#  'EX_htaxol_e': 0,
#  'EX_i_e': 0,
#  'EX_imp_e': 0,
#  'EX_ksi_e': 0,
#  'EX_ksii_core4_e': 0,
#  'EX_lac__D_e': 0,
#  'EX_cysi__L_e': 0,
#  'EX_leuktrB4_e': 0,
#  'EX_leuktrC4_e': 0,
#  'EX_leuktrD4_e': 0,
#  'EX_leuktrE4_e': 0,
#  'EX_limnen_e': 0,
#  'EX_lipoate_e': 0,
#  'EX_lnlc_e': 0,
#  'EX_lnlnca_e': 0,
#  'EX_lpchol_hs_e': 0,
#  'EX_meoh_e': 0,
#  'EX_mercplaccys_e': 0,
#  'EX_mthgxl_e': 0,
#  'EX_nad_e': 0,
#  'EX_nadp_e': 0,
#  'EX_nifedipine_e': 0,
#  'EX_npthl_e': 0,
#  'EX_nrpphr_e': 0,
#  'EX_oagd3_hs_e': 0,
#  'EX_oagt3_hs_e': 0,
#  'EX_ocdca_e': 0,
#  'EX_ocdcea_e': 0,
#  'EX_octa_e': 0,
#  'EX_onpthl_e': 0,
#  'EX_oxa_e': 0,
#  'EX_paf_hs_e': 0,
#  'EX_pchol_hs_e': 0,
#  'EX_perillyl_e': 0,
#  'EX_pheacgln_e': 0,
#  'EX_phllqne_e': 0,
#  'EX_phyt_e': 0,
#  'EX_prostgd2_e': 0,
#  'EX_prostge2_e': 0,
#  'EX_prostgf2_e': 0,
#  'EX_ps_hs_e': 0,
#  'EX_retfa_e': 0,
#  'EX_retinol_e': 0,
#  'EX_Rtotal2_e': 0,
#  'EX_Rtotal3_e': 0,
#  'EX_s2l2n2m2masn_e': 0,
#  'EX_sarcs_e': 0,
#  'EX_spc_hs_e': 0,
#  'EX_sph1p_e': 0,
#  'EX_strdnc_e': 0,
#  'EX_tag_hs_e': 0,
#  'EX_taxol_e': 0,
#  'EX_tchola_e': 0,
#  'EX_tcynt_e': 0,
#  'EX_tdchola_e': 0,
#  'EX_tetpent3_e': 0,
#  'EX_tetpent6_e': 0,
#  'EX_thmmp_e': 0,
#  'EX_thym_e': 0,
#  'EX_triodthy_e': 0,
#  'EX_triodthysuf_e': 0,
#  'EX_tststeroneglc_e': 0,
#  'EX_tststerones_e': 0,
#  'EX_ttdca_e': 0,
#  'EX_tymsf_e': 0,
#  'EX_Tyr_ggn_e': 0,
#  'EX_udp_e': 0,
#  'EX_vitd3_e': 0,
#  'EX_whddca_e': 0,
#  'EX_whhdca_e': 0,
#  'EX_whttdca_e': 0,
#  'EX_xoltri25_e': 0,
#  'EX_xoltri27_e': 0,
#  'F1Atg': 0,
#  'FACOAL140': 0,
#  'FACOAL160': 2,
#  'FACOAL170': 2,
#  'FACOAL181': 2,
#  'FACOAL1821': 1,
#  'FACOAL1822': 1,
#  'FACOAL1831': 1,
#  'FACOAL184': 1,
#  'FACOAL203': 1,
#  'FACOAL204': 2,
#  'FACOAL2042': 1,
#  'FACOAL205': 1,
#  'FACOAL2251': 1,
#  'FACOAL2252': 1,
#  'FACOAL240_1': 1,
#  'FACOAL241': 1,
#  'FACOAL245_1': 1,
#  'FACOAL40im': -1,
#  'FACOAL80': 2,
#  'FADH2tru': 0,
#  'FADH2tx': 0,
#  'FADtru': 0,
#  'FADtx': 0,
#  'FAEL184': 3,
#  'FAEL204': 3,
#  'FAEL205': 3,
#  'FAH1': -1,
#  'FAH2': -1,
#  'FALDH': 2,
#  'FALDtly': 0,
#  'FALDtm': 0,
#  'FAOXC11': 2,
#  'FAOXC16080m': 2,
#  'FAOXC16080x': 1,
#  'FAOXC180x': 1,
#  'FAOXC1811601m': 2,
#  'FAOXC1811603m': 2,
#  'FAOXC182806m': 2,
#  'FAOXC18280m': 2,
#  'FAOXC183806m': 2,
#  'FAOXC18480m': 2,
#  'FAOXC200180x': 1,
#  'FAOXC2031836m': 2,
#  'FAOXC204': 2,
#  'FAOXC2051843m': 2,
#  'FAOXC2051843x': 1,
#  'FAOXC2251836m': 2,
#  'FAOXC2252053m': 2,
#  'FAOXC2252053x': 1,
#  'GCHOLAte': 0,
#  'FAOXC226205m': 2,
#  'FAOXC2442246x': 1,
#  'FAOXC2452253x': 1,
#  'FAOXC2452256x': 1,
#  'FAOXC246226x': 1,
#  'FAOXC260240x_1': 1,
#  'FAS160COA': 2,
#  'FATP1t': 1,
#  'FATP2t': 0,
#  'FATP3t': 0,
#  'FATP7t': 1,
#  'FATP8t': 1,
#  'FBA5': -1,
#  'FDH': 0,
#  'FE2t': 0,
#  'FE3R2e_1': 2,
#  'FK': 1,
#  'FKYNH': 1,
#  'FORMCOAtx': 0,
#  'FORtm': 0,
#  'FORtr': 0,
#  'FPGS2': 1,
#  'FPGS2m': 1,
#  'FPGS3': 1,
#  'FPGS4_1': 1,
#  'FPGS4m_1': 1,
#  'FPGS5': 1,
#  'FPGS5m': 1,
#  'FPGS6m': 1,
#  'FPGS7m_1': 1,
#  'FPGS8m': 1,
#  'FPGS9': 1,
#  'FPGSm_1': 1,
#  'FRDPtc': 0,
#  'FRDPtr': 0,
#  'FRUt1r': 1,
#  'FTHFDH': 0,
#  'FTHFLmi': 3,
#  'FUC14GALACGLCGALGLUSIDEte': 0,
#  'FUC14GALACGLCGALGLUSIDEtg': 0,
#  'FUCACGALFUCGALACGLCGALGLUSIDEte': 0,
#  'FUCACNGAL14ACGLCGALGLUSIDEte': 0,
#  'FUCACNGAL14ACGLCGALGLUSIDEtg': 0,
#  'FUCACNGALACGLCGALGLUSIDEte': 0,
#  'FUCASE2ly': 1,
#  'FUCASEe': 2,
#  'FUCFUC132GALACGLCGAL14ACGLCGALGLUSIDEte': 0,
#  'FUCFUC132GALACGLCGAL14ACGLCGALGLUSIDEtg': 0,
#  'FUCFUCFUCGALACGLC13GALACGLCGAL14ACGLCGALGLUSIDEte': 0,
#  'FUCFUCFUCGALACGLC13GALACGLCGAL14ACGLCGALGLUSIDEtg': 0,
#  'FUCFUCFUCGALACGLCGAL14ACGLCGALGLUSIDEte': 0,
#  'FUCFUCFUCGALACGLCGAL14ACGLCGALGLUSIDEtg': 0,
#  'FUCGALFUCGALACGLCGALGLUSIDEtg': 0,
#  'FUCGALGBSIDEte': 0,
#  'FUCGALGBSIDEtg': 0,
#  'FUCtly': 0,
#  'FUMAC': 1,
#  'FUMSO4tm': 1,
#  'FUMtm': 1,
#  'FUT15g': 0,
#  'FUT16g': 0,
#  'FUT32g': -1,
#  'FUT911g': -1,
#  'FUT91g': -1,
#  'FUT94g': -1,
#  'FUT96g': -1,
#  'FUT97g': -1,
#  'FUT99g': -1,
#  'G14T20g': 2,
#  'G14T21g': 2,
#  'G14T2g': 2,
#  'G14T5g': 2,
#  'G5SDym': 2,
#  'G6PDH1er': 0,
#  'G6PDH2er': 3,
#  'G6PPer': 2,
#  'GABAVESSEC_1': -1,
#  'GACMTRc': 1,
#  'GACPAILter': 0,
#  'GALACGLCGALGBSIDEte': 0,
#  'GALACGLCGALGBSIDEtg': 0,
#  'GALASE10ly': 0,
#  'GALASE12ly': 0,
#  'GALASE13ly': 0,
#  'GALASE15ly': 0,
#  'GALASE16ly': 0,
#  'GALASE17ly': 0,
#  'GALASE19ly': 0,
#  'GALASE1ly': 0,
#  'GALASE20ly': 0,
#  'GALASE4ly': 0,
#  'GALASE7ly': 0,
#  'GALASE8ly': 0,
#  'GALASE9ly': 0,
#  'GALFUC12GAL14ACGLCGALGLUSIDEtg': 0,
#  'GALGALFUCFUCGALACGLCGALACGLCGAL14ACGLCGALGLUSIDEte': 0,
#  'GALGALFUCFUCGALACGLCGALACGLCGAL14ACGLCGALGLUSIDEtg': 0,
#  'GALGALGALTHCRMtg': 0,
#  'GALGT2': 0,
#  'GALGT3': 0,
#  'GALNACT1g': 2,
#  'GALNACT2g': 2,
#  'GALNACT3g': 2,
#  'GALNACT4g': 2,
#  'GALNACT5g': 2,
#  'GALSIDEtg': 0,
#  'GALSIDEtl': 0,
#  'GALt1r': 2,
#  'GALT2g': 0,
#  'GALtly': 0,
#  'GAO1g': 1,
#  'GARFT': 2,
#  'GASNASE2ly': 2,
#  'GASNASEly': 2,
#  'GBA': 2,
#  'GBGT1': -1,
#  'GBSIDEte': 0,
#  'GBSIDEtl': 0,
#  'GCCam': 0,
#  'GCHOLAt2': 0,
#  'GD1B2te': 0,
#  'GD1Cte': 0,
#  'GDPFUCtg': 0,
#  'GFUCS': 2,
#  'GGH_10FTHF7GLUl': 2,
#  'GGH_5THFl': 2,
#  'GGH_6DHFl': 2,
#  'GGH_7THFe': 2,
#  'GGLUCT': 2,
#  'GHMT2rm': 3,
#  'GLAl': 2,
#  'GLB1': 0,
#  'GLCAASE4ly': 1,
#  'GLCAASE6ly': 1,
#  'GLCAASE7ly': 1,
#  'GLCAASE8ly': 1,
#  'GLCAASE9ly': 1,
#  'GLCAT4g': 0,
#  'GLCAT5g': 0,
#  'GLCAT6g': 1,
#  'GLCAT7g': 1,
#  'GLCAT8g': 1,
#  'GLCNACASE5ly': 1,
#  'GLCNACDASg': 1,
#  'GLCNACT2g': 1,
#  'GLCNACT5g': 1,
#  'GLCter': 0,
#  'GLCtly': 0,
#  'GLGNS1': 1,
#  'GLNALANaEx': 2,
#  'GLNASNNaEx': 2,
#  'GLNCYSNaEx': 2,
#  'GLNtm': 0,
#  'GLPASE1': 2,
#  'GLPASE2': 2,
#  'GLRASE': 0,
#  'GLUt6': 0,
#  'GLXO2p': 0,
#  'GLXtp': 0,
#  'GLYAMDTRc': 0,
#  'GLYBt4_2_r': 1,
#  'GLYCK2': 0,
#  'GLYCLTDym': 0,
#  'GLYCLTtp': 0,
#  'GLYC_St': 0,
#  'GLYOp': 0,
#  'GLYt4': 3,
#  'GLYt7_211_r': 1,
#  'GLYtm': 0,
#  'GLYVESSEC_1': -1,
#  'GMPtg': 0,
#  'GMPtn': 0,
#  'GNDer': 1,
#  'GNMT': -1,
#  'GP1CALPHAtg': 0,
#  'GPAM_hs_1': 2,
#  'GPIDA2er': 2,
#  'GPIDAer': 2,
#  'GQ1BALPHAte': 0,
#  'GQ1Btg': 0,
#  'GT1Ate': 0,
#  'GT1Atg': 0,
#  'DHAOX_c': 0,
#  'GTHOm': 2,
#  'GTHPi': 3,
#  'GTHPm': 3,
#  'GTHS': 1,
#  'GULLACter': 0,
#  'GULN3D': 0,
#  'GULNDer': 0,
#  'GULNter': 0,
#  'GUR1PP': 0,
#  'HCO3Em': 2,
#  'H2O2syn': 0,
#  'H2O2t': 0,
#  'H2O2tm': 0,
#  'H2Oter': 0,
#  'H2Otg': 0,
#  'H3MTer_U': 1,
#  'H4ET3er': 1,
#  'H4ETer': 1,
#  'H6ET3er': 1,
#  'H7ET2er': 1,
#  'HACD1x': 1,
#  'HACD9m': 1,
#  'HAS1': 1,
#  'HAtly': 0,
#  'HBZOPT10m': 2,
#  'HCO3_CLt': 1,
#  'HCOUMARINte': 0,
#  'HDCAt': 1,
#  'HDD2COAtx': 0,
#  'HESTRATRIOLte': 0,
#  'HESTRATRIOLtr': 0,
#  'HEX4': 1,
#  'HEXCt': 0,
#  'HISDC': 0,
#  'HISt4': 3,
#  'HISTAVESSEC_1': 0,
#  'HMGCOASm': -1,
#  'HMGCOAtm': 0,
#  'HMGCOAtx': 0,
#  'HMGLm': 1,
#  'HMGLx': 1,
#  'HOMt4': 1,
#  'HPACtr': 0,
#  'HPDCACRNCPT1': 1,
#  'HPDCACRNCPT2': 0,
#  'HPYRDCm': 0,
#  'HPYRR2x_1': 3,
#  'HPYRtp': 0,
#  'HS2ly': 1,
#  'HSAT2ly': 0,
#  'HSAT3ly': 0,
#  'HSD17B42x_1': 1,
#  'HSD17B4x': 1,
#  'HSD17B7r': 2,
#  'HSD17B8r': 0,
#  'HSD17B9r': 2,
#  'HSD3A1r': 0,
#  'HSD3B11': -1,
#  'HSD3B12r': -1,
#  'HSD3B13': -1,
#  'HSD3B3r': -1,
#  'HSD3B7P': 1,
#  'HSPASEly': 0,
#  'HSPGt': 0,
#  'HTAXOLte': 0,
#  'Htx': 0,
#  'HXANtx': 0,
#  'HYPTROX_cho': 0,
#  'ICDHyr': 2,
#  'ICDHyp': 2,
#  'IDHPOXOX2b': 0,
#  'IDHPOXOX3': 0,
#  'IDHPOXOX4': 0,
#  'IDHPOXOXb': 0,
#  'IDOAASE3ly': 0,
#  'IDOAASE4ly': 0,
#  'IDOURtly': 1,
#  'IDPtn': 0,
#  'ILEt4': -1,
#  'ILEtmi': 0,
#  'ILETAm': 1,
#  'INOSTO': 0,
#  'INSt': 2,
#  'INSTt2': 0,
#  'INSTt4': 0,
#  'IPDPtx': 0,
#  'ITCOALm': 1,
#  'ITPtn': 0,
#  'KAS8': 2,
#  'KCC2t': 1,
#  'KCCt': 1,
#  'KHK': 1,
#  'KHK2': 1,
#  'KSII_CORE2tly': 0,
#  'KSII_CORE4t': 0,
#  'KSItly': 0,
#  'KYN3OX': 0,
#  'KYNATESYN': 0,
#  'LACZe': 0,
#  'LALDO': 2,
#  'LAPCOAl': 1,
#  'LCADi_D': 2,
#  'LCTStg': 0,
#  'LCYSTAT': 2,
#  'LCYSTCBOXL': 1,
#  'LEUKTRA4tr': 0,
#  'LEUKTRB4t': -1,
#  'LEUKTRB4tr': 0,
#  'LEUKTRC4t': 2,
#  'LEUKTRD4t': 0,
#  'LEUKTRE4t': -1,
#  'LEUKTRF4t': -1,
#  'LEUTAm': 1,
#  'TTCCOAtx': 0,
#  'LIMNENte': 0,
#  'LINKDEG1ly': 0,
#  'LINKDEG2ly': 0,
#  'LINKDEG3ly': 0,
#  'LIPOti_1': 1,
#  'L_LACtcm': -1,
#  'LNLCCPT1': 1,
#  'LNLCCPT2': 0,
#  'LNLCCRNt': 0,
#  'LNLCt': 1,
#  'LNLNCAt': 1,
#  'LNLNCGCPT2': 0,
#  'LNLNCGCRNt': 0,
#  'LNLNCGt': 1,
#  'LPASE': 0,
#  'LPS2': 0,
#  'LPS3e': 0,
#  'LPS4e': -1,
#  'LRAT1': 0,
#  'LRAT2': 0,
#  'LSTO1r': 1,
#  'LTC4CP': 0,
#  'LTC4Sr': 1,
#  'LTDCL': 0,
#  'LYSt4': 1,
#  ...}

# %%
if require_biomass:
    opt_control = CORDA(model, conf_control, met_prod = biomass)
else:
    opt_control = CORDA(model, conf_control)
opt_control.build()
print(opt_control)
# Out:
# build status: reconstruction complete
# Inc. reactions: 1777/10600
#  - unclear: 1031/6028
#  - exclude: 5/1022
#  - low and medium: 268/3077
#  - high: 473/473

# %%
with open(f'{folder}\\control.pickle', 'wb') as handle:
    pickle.dump(opt_control, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
model_control = opt_control.cobra_model()

# %%
if require_biomass:
    model_control.add_reactions([model.reactions.BIOMASS_maintenance])
    model_control.objective=model.objective

# %%
model_control.summary()
# Out:
# <h3>Objective</h3><p>1.0 BIOMASS_maintenance = 0.0</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
cobra.io.write_sbml_model(model_control, f'{folder}\\model_control.xml')

# %%
test = cobra.io.read_sbml_model(f'{folder}\\model_control.xml')

# %%
#test.summary()

# %% [markdown]
# ### Knockdown

# %%
thr0 = np.percentile(df_kd.value, perc0)
thr1 = np.percentile(df_kd.value, perc1)
thr2 = np.percentile(df_kd.value, perc2)
thr3 = np.percentile(df_kd.value, perc3)

# %%
gene_conf_kd = {g_id : val_to_score(val, thr0, thr1, thr2, thr3) for (g_id, val) in zip(df_kd['gene_id'], df_kd['value'])}

# %%
conf_kd = {}
for r in model.reactions:
    conf_kd[r.id] = reaction_confidence(r, gene_conf_kd)

# %%
if require_biomass:
    opt_kd = CORDA(model, conf_kd, met_prod = biomass)
else:
    opt_kd = CORDA(model, conf_kd)
opt_kd.build()
print(opt_kd)
# Out:
# build status: reconstruction complete
# Inc. reactions: 2027/10600
#  - unclear: 1164/6158
#  - exclude: 8/1068
#  - low and medium: 324/2843
#  - high: 531/531

# %%
with open(f'{folder}\\kd.pickle', 'wb') as handle:
    pickle.dump(opt_kd, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
#with open('models\\kd.pickle', 'rb') as handle:
#    opt_kd = pickle.load(handle)

# %%
model_kd = opt_kd.cobra_model()

# %%
if require_biomass:
    model_kd.add_reactions([model.reactions.BIOMASS_maintenance])
    model_kd.objective=model.objective

# %%
model_kd.summary()
# Out:
# Non-linear or non-reaction model objective. Falling back to minimal display.
# <h3>Objective</h3><p>nan Expression = nan</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
cobra.io.write_sbml_model(model_kd, f'{folder}\\model_kd.xml')
